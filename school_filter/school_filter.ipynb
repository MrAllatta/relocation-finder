# %%
import pandas as pd
import requests

# --- CONFIGURATION ---
SCHOOL_QUALITY_BASE_URL = "https://data.cityofnewyork.us/resource/dnpx-dfnc.json"
SCHOOL_DEMOGRAPHICS_BASE_URL = "https://data.cityofnewyork.us/resource/c7ru-d68s.json"
APP_TOKEN = None  # Optional: Add your Socrata app token if you have one

# %%
# --- GENERIC QUERY BUILDER ---
def build_soql_query(select_fields=None, where_clause=None, limit=5000, offset=0, order_by=None):
    params = {}
    if select_fields:
        params['$select'] = ','.join(select_fields)
    if where_clause:
        params['$where'] = where_clause
    if limit:
        params['$limit'] = limit
    if offset:
        params['$offset'] = offset
    if order_by:
        params['$order'] = order_by
    return params

# --- DATA FETCHER ---
def fetch_data(base_url, params):
    headers = {}
    if APP_TOKEN:
        headers['X-App-Token'] = APP_TOKEN

    response = requests.get(base_url, params=params, headers=headers)
    response.raise_for_status()
    return pd.DataFrame(response.json())

# --- JOINER ---
def join_quality_and_demographics(quality_df, demographics_df):
    # Normalize DBN fields if necessary
    return pd.merge(quality_df, demographics_df, left_on='dbn', right_on='dbn', how='left')

# %%
quality_select_fields = [
    "dbn", "school_name", "report_type", "metric_display_name", "metric_variable_name", "metric_value",
    "metric_score", "number_of_students", "school_year", "report_year", "school_type"
]

quality_params = build_soql_query(
    select_fields=quality_select_fields,
    where_clause="report_year = 2024 AND metric_value IS NOT NULL",
    limit=500000
)

quality_df = fetch_data(SCHOOL_QUALITY_BASE_URL, quality_params)
quality_df['metric_value'] = pd.to_numeric(quality_df['metric_value'], errors='coerce')
print(f"Fetched {len(quality_df)} rows of school quality data.")
# Out:
# Fetched 166141 rows of school quality data.

# %%
quality_df['metric_display_name'].unique()
# Out:
# array(['Average Student Attendance',
#        'Percentage of Students with >90% Attendance',
#        'Percentage of Students with >90% Attendance - Black',
#        'Percentage of Students with >90% Attendance - Hispanic',
#        'Percentage of Students with >90% Attendance - Female',
#        'Percentage of Students with >90% Attendance - Male',
#        'MS Adjusted Core Course Pass Rate of Former Students',
#        'Movement of Students with IEPs to Less Restrictive Environments',
#        'ELL Progress',
#        'Percentage of Students at Level 3 or 4, ELA, Grade 3',
#        'Percentage of Students at Level 3 or 4, ELA, Grade 4',
#        'Percentage of Students at Level 3 or 4, ELA, Grade 5',
#        'Percentage of Students at Level 3 or 4, ELA',
#        'Percentage of Students at Level 3 or 4, ELA - Black',
#        'Percentage of Students at Level 3 or 4, ELA - Hispanic or Latinx',
#        'Percentage of Students at Level 3 or 4, ELA - Female',
#        'Percentage of Students at Level 3 or 4, ELA - Male',
#        'Percentage of Students at Level 3 or 4, ELA - Students with IEPs',
#        'Percentage of Students at Level 3 or 4, Math, Grade 3',
#        'Percentage of Students at Level 3 or 4, Math, Grade 4',
#        'Percentage of Students at Level 3 or 4, Math, Grade 5',
#        'Percentage of Students at Level 3 or 4, Math',
#        'Percentage of Students at Level 3 or 4, Math - Black',
#        'Percentage of Students at Level 3 or 4, Math - Hispanic or Latinx',
#        'Percentage of Students at Level 3 or 4, Math - Female',
#        'Percentage of Students at Level 3 or 4, Math - Male',
#        'Percentage of Students at Level 3 or 4, Math - Students with IEPs',
#        'Average Student Proficiency, ELA, Grade 3',
#        'Average Student Proficiency, ELA, Grade 4',
#        'Average Student Proficiency, ELA, Grade 5',
#        'Average Student Proficiency, ELA',
#        'Average Student Proficiency, ELA - Black',
#        'Average Student Proficiency, ELA - Hispanic or Latinx',
#        'Average Student Proficiency, ELA - Female',
#        'Average Student Proficiency, ELA - Male',
#        'Average Student Proficiency, ELA - Integrated Co-Teaching',
#        'Average Student Proficiency, ELA - Integrated Co-Teaching and SETSS',
#        'Average Student Proficiency, ELA - English Language Learners',
#        'Average Student Proficiency, ELA - Lowest Third Citywide',
#        "Average Student Proficiency, ELA - School's Lowest Third",
#        'Average Student Proficiency, ELA - Black or Hispanic Males in Lowest Third Citywide',
#        'Average Student Proficiency, Math, Grade 3',
#        'Average Student Proficiency, Math, Grade 4',
#        'Average Student Proficiency, Math, Grade 5',
#        'Average Student Proficiency, Math',
#        'Average Student Proficiency, Math - Black',
#        'Average Student Proficiency, Math - Hispanic or Latinx',
#        'Average Student Proficiency, Math - Female',
#        'Average Student Proficiency, Math - Male',
#        'Average Student Proficiency, Math - Integrated Co-Teaching',
#        'Average Student Proficiency, Math - Integrated Co-Teaching and SETSS',
#        'Average Student Proficiency, Math - English Language Learners',
#        'Average Student Proficiency, Math - Lowest Third Citywide',
#        'Average Student Proficiency, Math - Black or Hispanic Males in Lowest Third Citywide',
#        'Percentage of Students with >90% Attendance - Asian',
#        'Percentage of Students with >90% Attendance - White',
#        'Percentage of Students at Level 3 or 4, ELA - Asian',
#        'Percentage of Students at Level 3 or 4, ELA - English Language Learners',
#        'Percentage of Students at Level 3 or 4, Math - Asian',
#        'Percentage of Students at Level 3 or 4, Math - English Language Learners',
#        'Average Student Proficiency, ELA - Asian',
#        'Average Student Proficiency, Math - Asian',
#        "Average Student Proficiency, Math - School's Lowest Third",
#        '9th Grade Adjusted Credit Accumulation of Former 8th Graders',
#        '% of 8th Graders earning High School Credit in Language other than English',
#        '% of 8th Graders earning High School Credit in Math',
#        '% of 8th Graders taking accelerated courses who passed',
#        '% of 8th Graders taking Math accelerated courses who passed',
#        '% of 8th Graders taking Science accelerated courses who passed',
#        'Percentage of Students at Level 3 or 4, ELA, Grade 7',
#        '% of 8th Graders earning High School Credit in Science',
#        '% of 8th Graders taking any accelerated courses',
#        '% of 8th Graders taking accelerated Language other than English courses',
#        '% of 8th Graders taking accelerated Math courses',
#        '% of 8th Graders taking accelerated Science courses',
#        'Percent of 8th Graders Earning HS Credit',
#        'ELA Core Course Pass Rate', 'Math Core Course Pass Rate',
#        'Science Core Course Pass Rate',
#        'Social Studies Core Course Pass Rate',
#        'Percentage of Students at Level 3 or 4, ELA, Grade 6',
#        'Percentage of Students at Level 3 or 4, ELA, Grade 8',
#        'Percentage of Students at Level 3 or 4, Math, Grade 6',
#        'Percentage of Students at Level 3 or 4, Math, Grade 7',
#        'Percentage of Students at Level 3 or 4, Math, Grade 8',
#        'Average Student Proficiency, ELA, Grade 6',
#        'Average Student Proficiency, ELA, Grade 7',
#        'Average Student Proficiency, ELA, Grade 8',
#        'Average Student Proficiency, ELA - Special Class',
#        'Average Student Proficiency, Math, Grade 6',
#        'Average Student Proficiency, Math, Grade 7',
#        'Average Student Proficiency, Math, Grade 8',
#        'Percentage of Students at Level 2 or Higher in 5th Grade (Out of Students at Level 1 in 3rd Grade), Math',
#        'Percentage of Students at Level 3 or 4 in 5th Grade (Out of Students at Level 2 in 3rd Grade), ELA',
#        'Percentage of Students at Level 3 or 4, ELA - White',
#        'Percentage of Students at Level 3 or 4, Math - White',
#        'Percentage of Students at Level 3 or 4 in 5th Grade (Out of Students at Level 3 or 4 in 3rd Grade), ELA',
#        'Percentage of Students at Level 3 or 4 in 5th Grade (Out of Students at Level 3 or 4 in 3rd Grade), Math',
#        'Average Student Proficiency, ELA - White',
#        'Average Student Proficiency, Math - White',
#        'Average Student Proficiency, Math - Special Class',
#        'Percentage of Students at Level 3 or 4, Science, Grade 8',
#        'Percentage of Students with >90% Attendance - Multiracial',
#        '% of 8th Graders taking Language other than English accelerated courses who passed',
#        'Percentage of Students at Level 3 or 4, ELA - Multiracial',
#        'Percentage of Students at Level 3 or 4, Math - Multiracial',
#        'Average Student Proficiency, ELA - Multiracial',
#        'Average Student Proficiency, Math - Multiracial',
#        '4-Year College and Career Readiness - All Students',
#        '4-Year College and Career Readiness - Black',
#        '4-Year College and Career Readiness - Hispanic or Latinx',
#        '4-Year College and Career Readiness - Female',
#        '4-Year College and Career Readiness - Male',
#        '6-Year College and Career Readiness - All Students',
#        '% of cohort who took the ACT English exam',
#        '% of cohort who took the ACT Math exam',
#        '% of cohort who took the ACT Reading exam',
#        '% of cohort who took the ACT Science exam',
#        '10+ Credits in 1st Year - All Students',
#        "10+ Credits in 1st Year - School's Lowest Third",
#        '10+ Credits in 1st Year - Black',
#        '10+ Credits in 1st Year - Hispanic or Latinx',
#        '10+ Credits in 1st Year - Female',
#        '10+ Credits in 1st Year - Male',
#        '10+ Credits in 2nd Year - All Students',
#        "10+ Credits in 2nd Year - School's Lowest Third",
#        '10+ Credits in 2nd Year - Black',
#        '10+ Credits in 2nd Year - Hispanic or Latinx',
#        '10+ Credits in 2nd Year - Female',
#        '10+ Credits in 2nd Year - Male',
#        '10+ Credits in 3rd Year - All Students',
#        '10+ Credits in 3rd Year - Asian',
#        '10+ Credits in 3rd Year - Hispanic',
#        '10+ Credits in 3rd Year - Female',
#        '10+ Credits in 3rd Year - Male',
#        '4-Year Graduation Rate - All Students',
#        '4-Year Graduation Rate - Black',
#        '4-Year Graduation Rate - Hispanic or Latinx',
#        '4-Year Graduation Rate - Female', '4-Year Graduation Rate - Male',
#        '4-Year Graduation Rate - Special Class, Integrated Co-Teaching, or SETSS',
#        '4-Year Graduation Rate - Excluding NYSAA',
#        '6-Year Graduation Rate - All Students',
#        '6-Year Graduation Rate - Black',
#        '6-Year Graduation Rate - Hispanic or Latinx',
#        '6-Year Graduation Rate - Female', '6-Year Graduation Rate - Male',
#        '6-Year Graduation Rate - Excluding NYSAA',
#        'Percentage of Students Who Graduated in 4 Years (Out of Students at Level 1 in 8th Grade)',
#        'Percentage of Students Who Graduated in 4 Years (Out of Students at Level 2 in 8th Grade)',
#        'Average Regents Score - Algebra II',
#        'Average Regents Score for Students with IEPs - Global History',
#        'Average Regents Score for Students with IEPs - Algebra I',
#        'Average Regents Score - Chemistry',
#        'Average Regents Score - English',
#        'Average Regents Score - Earth Science',
#        'Average Regents Score - Geometry',
#        'Average Regents Score - Global History',
#        'Average Regents Score - US History',
#        'Average Regents Score - Algebra I',
#        'Average Regents Score - Living Environment',
#        'Average Regents Score - Languages Other Than English',
#        '% Scoring 4+ on any IB Exam',
#        'Average score of students in the current cohort who took the SAT Math exam',
#        'Average score of students in the current cohort who took the SAT Reading and Writing exam',
#        'Average Completion Rate for Remaining Regents',
#        'Average Completion Rate for Remaining Regents - Asian',
#        'Average Completion Rate for Remaining Regents - Black',
#        'Average Completion Rate for Remaining Regents - Hispanic or Latinx',
#        'Average Completion Rate for Remaining Regents - Female',
#        'Average Completion Rate for Remaining Regents - Male',
#        '4-Year High School Persistence Rate',
#        '4-Year High School Persistence Rate - Black',
#        '4-Year High School Persistence Rate - Hispanic',
#        '4-Year High School Persistence Rate - Female',
#        '4-Year High School Persistence Rate - Male',
#        '6-Year High School Persistence Rate',
#        '6-Year High School Persistence Rate - Black',
#        '6-Year High School Persistence Rate - Hispanic',
#        '6-Year High School Persistence Rate - Female',
#        '6-Year High School Persistence Rate - Male',
#        'Postsecondary Enrollment Rate - 18 Months',
#        'Postsecondary Enrollment in CUNY 2-Year (18 months)',
#        'Postsecondary Enrollment in CUNY 4-Year (18 months)',
#        'Postsecondary Enrollment in Out of State Non-Profit (18 months)',
#        'Postsecondary Enrollment in For-Profit (18 months)',
#        'Postsecondary Enrollment in NYS Private Non-Profit (18 months)',
#        'Postsecondary Enrollment in NYS Public (18 months)',
#        'Postsecondary Enrollment in Public Service (18 months)',
#        'Postsecondary Enrollment in Vocational Program (18 months)',
#        'Postsecondary Enrollment Rate - 6 Months',
#        'Postsecondary Enrollment Rate - 6 Months - Hispanic or Latinx',
#        'Postsecondary Enrollment Rate - 6 Months - Female',
#        'Postsecondary Enrollment Rate - 6 Months - Male',
#        'Postsecondary Enrollment in CUNY 2-Year (6 months)',
#        'Postsecondary Enrollment in CUNY 4-Year (6 months)',
#        'Postsecondary Enrollment in Out of State Non-Profit (6 months)',
#        'Postsecondary Enrollment in For-Profit (6 months)',
#        'Postsecondary Enrollment in NYS Private Non-Profit (6 months)',
#        'Postsecondary Enrollment in NYS Public (6 months)',
#        'Postsecondary Enrollment Rate - 6 Months, Lowest Third Citywide',
#        'Postsecondary Enrollment in Other (6 months)',
#        'Postsecondary Enrollment in Public Service (6 months)',
#        'Postsecondary Enrollment in Vocational Program (6 months)',
#        '% of students in the current cohort who took the ACT English exam who scored 20+',
#        '% of students in the current cohort who took the ACT Math exam who scored 21+',
#        '% of students in the current cohort who took the SAT Math exam who passed the college ready threshold',
#        '% of students in the current cohort who took the SAT Reading and Writing exam and scored 480+',
#        '% of students who took the Algebra II Regents exam and are college ready (scored 65+)',
#        '% of students who took the English Regents exam and are college ready (scored 70+)',
#        '% of students who took the Geometry Regents exam and are college ready (scored 70+)',
#        '% of students who took the Algebra I Regents exam and are college ready (scored 70+)',
#        'College and Career Preparatory Course Index',
#        'College and Career Preparatory Course Index - Black',
#        'College and Career Preparatory Course Index - Hispanic or Latinx',
#        'College and Career Preparatory Course Index - Female',
#        'College and Career Preparatory Course Index - Male',
#        '% Scoring 3+ on any AP Exam',
#        '% Passing a NYCPS-certified CPCC Course',
#        '% Passing an Industry-Recognized Technical Assessment',
#        "% Earning a Grade of 'C' or Higher for College Credit",
#        '% Scoring 65+ on Alg2, Chem, or Phys Regents Exam',
#        '% Earning a Diploma with an Arts Endorsement',
#        '% Earning a Diploma with a CTE Endorsement',
#        '% Attaining Regents Diploma (4 year)',
#        '% Attaining Regents Diploma (6 year)',
#        '% of students who took the Algebra II Regents exam in the current year who scored 65+',
#        '% of students who took the Chemistry Regents in the current year who scored 65+',
#        '% of students who took the English Regents exam in the current year who scored 65+',
#        '% of students who took the Earth Science Regents in the current year who scored 65+',
#        '% of students who took the Geometry Regents exam in the current year who scored 65+',
#        '% of students who took the Global History Regents in the current year who scored 65+',
#        '% of students who took the US History Regents in the current year who scored 65+',
#        '% of students who took the Algebra I Regents exam in the current year who scored 65+',
#        '% of students who took the Living Environment Regents in the current year who scored 65+',
#        '% of students who took a Languages Other Than English Regents in the current year who scored 65+',
#        'College Persistence',
#        '4-Year College and Career Readiness - Asian',
#        '10+ Credits in 1st Year - Asian',
#        '10+ Credits in 1st Year - White',
#        '10+ Credits in 2nd Year - Asian',
#        '10+ Credits in 3rd Year - Black',
#        '4-Year Graduation Rate - Asian',
#        '4-Year Graduation Rate - English Language Learners',
#        '6-Year Graduation Rate - Asian',
#        'Percentage of Students Who Graduated in 4 Years (Out of Students at Level 3 or 4 in 8th Grade)',
#        'Average Regents Score for Students with IEPs - English',
#        'Average Regents Score for Students with IEPs - US History',
#        'Average Regents Score for Students with IEPs - Living Environment',
#        'Average Regents Score for English Lang. Learners - English',
#        '4-Year High School Persistence Rate - Asian',
#        '6-Year High School Persistence Rate - Asian',
#        'Postsecondary Enrollment Rate - 6 Months - Asian',
#        'Postsecondary Enrollment Rate - 6 Months - Black',
#        'College and Career Preparatory Course Index - Asian',
#        '4-Year College and Career Readiness - White',
#        '10+ Credits in 2nd Year - White',
#        '4-Year Graduation Rate - White', '6-Year Graduation Rate - White',
#        '4-Year High School Persistence Rate - White',
#        '6-Year High School Persistence Rate - White',
#        'Postsecondary Enrollment Rate - 6 Months - White',
#        'College and Career Preparatory Course Index - White',
#        'Average Change in Student Attendance',
#        '% of 4-Year Cohort Taking ACT English',
#        '% of 4-Year Cohort Taking ACT Math',
#        '% of 4-Year Cohort Taking ACT Reading',
#        '% of 4-Year Cohort Taking ACT Science',
#        '% of 4-Year Cohort Taking SAT Math',
#        '% of cohort who took the SAT Reading and Writing exam',
#        'Credit Accumulation Per Year, Students Beginning with 0.00 - 11.00 Credits',
#        'Credit Accumulation Per Year, Students Beginning with 11.01 - 22.00 Credits',
#        'Credit Accumulation Per Year, Students Beginning with 22.01 - 33.00 Credits',
#        'Credit Accumulation Per Year, Students Beginning with 33.01 - 38.00 Credits',
#        'Transfer School Graduation Rate',
#        'Transfer School Graduation Rate - Black',
#        'Transfer School Graduation Rate - Hispanic or Latinx',
#        'Transfer School Graduation Rate - Female',
#        'Transfer School Graduation Rate - Male',
#        'Transfer School Graduation Rate - Overage/Under-Credited Black or Hispanic Males',
#        'Transfer School Graduation Rate - Special Class, Integrated Co-Teaching, SETSS',
#        'Transfer School Graduation Rate - Most-at-Risk Overage/Under-Credited Students',
#        'Transfer School Graduation Rate - Non-Overage/Under-Credited Students',
#        'Transfer School Graduation Rate - Overage/Under-Credited',
#        'HST Persistence Rate',
#        'Postsecondary Enrollment Rate - 6 Months, Overage/Under-Credited',
#        'College and Career Preparatory Course Index, Overage/Under-Credited',
#        'Transfer School Graduation Rate - Asian',
#        'Transfer School Graduation Rate - English Language Learners',
#        'Transfer School Graduation Rate - Other Overage/Under-Credited Students',
#        'Average Regents Score for English Lang. Learners - Global History',
#        'Average Regents Score for English Lang. Learners - US History',
#        'Average Regents Score for English Lang. Learners - Algebra I',
#        'Average Regents Score for English Lang. Learners - Living Environment',
#        'Average Score SAT Math', '% Passing Regents Earth Science',
#        '% Passing Regents Global History', '% Passing Regents US History',
#        '% Passing Regents Living Environment',
#        '% Passing Regents Languages Other Than English',
#        'Average Student Proficiency, ELA - SETSS',
#        'Average Student Proficiency, Math - SETSS',
#        '10+ Credits in 3rd Year - White',
#        'Average score of students in the current cohort who took the ACT English exam',
#        'Average score of students in the current cohort who took the ACT Math exam',
#        'Average score of students in the current cohort who took the ACT Reading exam',
#        'Average score of students in the current cohort who took the ACT Science exam',
#        'Average Regents Score - Physics',
#        'Average Completion Rate for Remaining Regents - Multiracial',
#        'Average Completion Rate for Remaining Regents - White',
#        '% of students who took the Physics Regents in the current year who scored 65+',
#        'Percentage of Students at Level 3 or 4 in 5th Grade (Out of Students at Level 2 in 3rd Grade), Math',
#        'Percentage of Students with >90% Attendance - Native Hawaiian or Pacific Islander',
#        'Percentage of Students with >90% Attendance - Native American',
#        '4-Year College and Career Readiness - Multiracial',
#        '10+ Credits in 1st Year - Multiracial',
#        '10+ Credits in 2nd Year - Multiracial',
#        '10+ Credits in 3rd Year - Multiracial',
#        '4-Year Graduation Rate - Multiracial',
#        '6-Year Graduation Rate - Multiracial',
#        '4-Year High School Persistence Rate - Multiracial',
#        '6-Year High School Persistence Rate - Multiracial',
#        'Postsecondary Enrollment Rate - 6 Months - Multiracial',
#        'College and Career Preparatory Course Index - Multiracial',
#        'Transfer School Graduation Rate - White',
#        'Percentage of Students with >90% Attendance - Neither Female nor Male',
#        'Percentage of Students at Level 2 or Higher in 5th Grade (Out of Students at Level 1 in 3rd Grade), ELA',
#        'Percentage of Students at Level 3 or 4, ELA - Native American',
#        'Percentage of Students at Level 3 or 4, Math - Native American',
#        'Average Student Proficiency, ELA - Native American',
#        'Average Student Proficiency, Math - Native American',
#        '6-Year Graduation Rate - Native American',
#        '6-Year High School Persistence Rate - Native American',
#        'Average Completion Rate for Remaining Regents - Native Hawaiian or Pacific Islander',
#        'Average Completion Rate for Remaining Regents - Native American',
#        'NYSAA - ELA Percent at Level 1', 'NYSAA - ELA Percent at Level 2',
#        'NYSAA - ELA Percent at Level 3', 'NYSAA - ELA Percent at Level 4',
#        'NYSAA - Math Percent at Level 1',
#        'NYSAA - Math Percent at Level 2',
#        'NYSAA - Math Percent at Level 3',
#        'NYSAA - Math Percent at Level 4', 'Local Assessments',
#        'Standard English Assessments', 'Standard Math Assessments',
#        '10+ Credits in 1st Year - Native American',
#        'Percentage of Students at Level 3 or 4, ELA - Native Hawaiian or Pacific Islander',
#        'Percentage of Students at Level 3 or 4, Math - Native Hawaiian or Pacific Islander',
#        'Average Student Proficiency, ELA - Native Hawaiian or Pacific Islander',
#        'Average Student Proficiency, Math - Native Hawaiian or Pacific Islander',
#        '4-Year College and Career Readiness - Native American',
#        '10+ Credits in 2nd Year - Native American',
#        '10+ Credits in 3rd Year - Native American',
#        '4-Year Graduation Rate - Native American',
#        '6-Year Graduation Rate - Native Hawaiian or Pacific Islander',
#        '4-Year High School Persistence Rate - Native American',
#        '6-Year High School Persistence Rate - Native Hawaiian or Pacific Islander',
#        'Postsecondary Enrollment Rate - 6 Months - Native Hawaiian or Pacific Islander',
#        'College and Career Preparatory Course Index - Native American',
#        'Postsecondary Enrollment Rate - 6 Months - Native American',
#        'Average Student Proficiency, ELA - NYSAA',
#        'Average Student Proficiency, Math - NYSAA',
#        'Integration into Non-D75 Environment',
#        'Movement of Students to Less Restrictive Environments'],
#       dtype=object)

# %%
# Define filter conditions as a list of tuples: (metric_variable_name, min_value)
conditions = [
    ('attendance_k8_all', 0.90),
    ('chronic_absent_ems_all', 0.85),
    ('rating_mean_ela_all', 2.5),
    ('rating_mean_mth_all', 2.5),
    ('prof_pct_ela_3gr', 0.40),
    ('prof_pct_mth_3gr', 0.40)
]

# Create a mask: start True for all schools
schools_passing = pd.Series(True, index=quality_df['dbn'].unique())

for metric, threshold in conditions:
    # Find rows matching the metric
    metric_df = quality_df[quality_df['metric_variable_name'] == metric]

    # Schools that meet the threshold for this metric
    passing_this_metric = metric_df[metric_df['metric_value'] >= threshold]['dbn'].unique()

    # Update mask: only keep schools passing all conditions
    schools_passing &= schools_passing.index.isin(passing_this_metric)

# Filter final schools
final_dbns = schools_passing[schools_passing].index

# (Optional) Join back to school names or more info
final_schools = quality_df[quality_df['dbn'].isin(final_dbns)][['dbn', 'school_name']].drop_duplicates()

print(final_schools)

# Save results
final_schools.to_csv('filtered_schools_compound_tidy.csv', index=False)
# Out:
#            dbn                                        school_name
# 130     01M184                               P.S. 184m Shuang Wen
# 1697    01M539  New Explorations into Science, Technology and ...
# 1749    25Q130                                           P.S. 130
# 2454    02M006                           P.S. 006 Lillie D. Blake
# 2740    02M041                         P.S. 041 Greenwich Village
# ...        ...                                                ...
# 159206  84X255                Bronx Charter School for Excellence
# 162874  84X538                             Icahn Charter School 5
# 163261  84X579              Bronx Charter School for Excellence 2
# 163739  84X589              Bronx Charter School for Excellence 3
# 164216  84X608              Bronx Charter School for Excellence 4
#
# [78 rows x 2 columns]

# %%
demographics_select_fields = [
    "dbn", "school_name", "year",
    "total_enrollment", "english_language_learners_1", "students_with_disabilities_1",
    "asian_1", "black_1", "hispanic_1", "white_1", "missing_race_ethnicity_data_1",
    "poverty_1", "economic_need_index"
]

demographics_params = build_soql_query(
    select_fields=demographics_select_fields,
    where_clause="year='2021-22'",
    limit=5000
)

demographics_df = fetch_data(SCHOOL_DEMOGRAPHICS_BASE_URL, demographics_params)
print(f"Fetched {len(demographics_df)} rows of school demographics data.")
# Out:
# Fetched 1881 rows of school demographics data.

# %%
combined_df = join_quality_and_demographics(quality_df, demographics_df)
print(f"Joined dataset: {combined_df.shape[0]} rows, {combined_df.shape[1]} columns")

# %%
# Convert important columns to numeric
for col in ['metric_score', 'total_enrollment', 'poverty_1',
            'english_language_learners_1', 'students_with_disabilities_1',
            'asian_1', 'black_1', 'hispanic_1', 'white_1']:
    combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')

# %%
# Example: Search for aligned elementary schools
aligned_schools = combined_df[
    (combined_df['school_type'] == 'Elementary') &
    (combined_df['metric_score'] >= 3.5) &
    (combined_df['total_enrollment'] >= 300) &
    (combined_df['poverty_1'] <= 60) &
    (combined_df['white_1'] >= 20) &  # customize based on your own alignment needs
    (combined_df['black_1'] <= 50)
]

# Sort strongest signals first
aligned_schools = aligned_schools.sort_values('metric_score', ascending=False)

# Preview
aligned_schools[['school_name_x', 'dbn', 'metric_score', 'poverty_1',
                 'asian_1', 'black_1', 'hispanic_1', 'white_1']].head(20)

# %%
combined_df.head()
# Out:
#       dbn             school_name_x  \
# 0  02M933  City Knoll Middle School
# 1  12X211                  P.S. 211
# 2  11X299  Astor Collegiate Academy
# 3  01M020      P.S. 020 Anna Silver
# 4  01M020      P.S. 020 Anna Silver
#
#                           metric_display_name metric_value  metric_score  \
# 0                                ELL Progress         0.78          3.35
# 1                  Average Student Attendance        0.916           NaN
# 2                                ELL Progress        0.513           NaN
# 3  Average Student Proficiency, Math, Grade 5         2.21           NaN
# 4  Average Student Proficiency, Math, Grade 4         2.27           NaN
#
#   school_year report_year  school_type             school_name_y     year  \
# 0        2022        2023       Middle  City Knoll Middle School  2021-22
# 1        2022        2023   Elementary                  P.S. 211  2021-22
# 2        2022        2023  High School  Astor Collegiate Academy  2021-22
# 3        2022        2023   Elementary      P.S. 020 Anna Silver  2021-22
# 4        2022        2023   Elementary      P.S. 020 Anna Silver  2021-22
#
#    total_enrollment  english_language_learners_1  \
# 0               116                        0.155
# 1               408                        0.140
# 2               450                        0.120
# 3               351                        0.100
# 4               351                        0.100
#
#    students_with_disabilities_1  asian_1  black_1  hispanic_1  white_1  \
# 0                         0.371    0.060    0.207       0.612    0.112
# 1                         0.201    0.010    0.164       0.804    0.012
# 2                         0.216    0.091    0.267       0.462    0.151
# 3                         0.211    0.197    0.151       0.547    0.077
# 4                         0.211    0.197    0.151       0.547    0.077
#
#   missing_race_ethnicity_data_1  poverty_1 economic_need_index
# 0                           0.0        NaN               80.3%
# 1                           0.0        NaN               93.5%
# 2                         0.007        NaN               77.9%
# 3                         0.003        NaN               75.3%
# 4                         0.003        NaN               75.3%
